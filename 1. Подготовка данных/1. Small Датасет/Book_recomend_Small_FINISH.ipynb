# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt 
import numpy as np
import seaborn as sns

# %%
# загрузим датасет
processed_data = pd.read_csv('1/Books.csv')

df = pd.DataFrame(processed_data)

# %%
# from ydata_profiling import ProfileReport
# profile = ProfileReport(df,)
# profile.to_file('report1.html');

# %%
pd.set_option('display.max_columns', None)  # Показать все столбцы
pd.set_option('display.width', 1900)        # Установить ширину области отображения
pd.set_option('display.max_colwidth', None)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6810 entries, 0 to 6809
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   isbn13          6810 non-null   int64
#  1   isbn10          6810 non-null   object
#  2   title           6810 non-null   object
#  3   subtitle        2381 non-null   object
#  4   authors         6738 non-null   object
#  5   categories      6711 non-null   object
#  6   thumbnail       6481 non-null   object
#  7   description     6548 non-null   object
#  8   published_year  6804 non-null   float64
#  9   average_rating  6767 non-null   float64
#  10  num_pages       6767 non-null   float64
#  11  ratings_count   6767 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 638.6+ KB

# %%
# Удалим лишние столбцы:
df = df.drop(columns=['isbn13', 'isbn10', 'subtitle', 'thumbnail', 'published_year', 'num_pages', 'ratings_count'])
df.sample()
# Out:
#              title               authors categories                                                                                                                                                                                                                                                         description  average_rating
# 1588  Pacific Edge  Kim Stanley Robinson    Fiction  Set at the end of the 21st century in California, this story revolves around a seemingly perfect society. At first, bio-architect Kevin Claiborne thinks he has indeed found Utopia, but gradually events lead him to discover the corruption beneath the surface.            3.78

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6810 entries, 0 to 6809
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           6810 non-null   object
#  1   authors         6738 non-null   object
#  2   categories      6711 non-null   object
#  3   description     6548 non-null   object
#  4   average_rating  6767 non-null   float64
# dtypes: float64(1), object(4)
# memory usage: 266.1+ KB

# %%
# маска. Количество пропусков
null_d=df.isnull().sum()
print(null_d[null_d>0])
# Out:
# authors            72
# categories         99
# description       262
# average_rating     43
# dtype: int64

# %%
# Удаляем строки, имеющие пропуски в столбце description
df = df.dropna(subset=['description'])
df.info()
# маска. Количество пропусков
null_d=df.isnull().sum()
print(null_d[null_d>0])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6548 entries, 0 to 6809
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           6548 non-null   object
#  1   authors         6483 non-null   object
#  2   categories      6511 non-null   object
#  3   description     6548 non-null   object
#  4   average_rating  6511 non-null   float64
# dtypes: float64(1), object(4)
# memory usage: 306.9+ KB
# authors           65
# categories        37
# average_rating    37
# dtype: int64

# %%
# Проверка на дубликаты по столбцам 'title' и 'authors'
duplicates = df[df.duplicated(subset=['title', 'authors'], keep=False)]

# Вывод всех найденных дубликатов
print("Найдено дубликатов:", duplicates.shape[0])
print(duplicates)
# Out:
# Найдено дубликатов: 319
#                           title                      authors                              categories                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         description  average_rating
# 13     The Once and Future King        Terence Hanbury White                      Arthurian romances                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      An omnibus volume of the author's complete story of the Arthurian epic which includes: "The sword in the stone" (1939), "The witch in the wood" (1939), "The ill-made knight" (1940), "The candle in the wind" (published for the first time), and "The book of Merlyn." 1996.            4.04
# 16             Well of Darkness  Margaret Weis;Tracy Hickman                                     NaN  Gareth is just a frightened young lad when he is drafted in to be the whipping-boy for the unruly Prince Dagnarus. Yet as they grow to be men, an unshakable bond is formed. And it is their destiny for them to become the two most powerful - and feared - men in the kingdom. But when Dagnarus decides to become a knight himself, he begins a chain of evil events that threaten to destroy the entire kingdom. Only by uniting the Sovereign Stone can peace be restored, and it is up to Dagnarus' brother Helmos to try to achieve this impossible task, using his father's soldiers against his brother's army. All the while, Gareth is gaining mastery over the sinister Void magic, and he is devoted to helping his childhood companion.. This gripping story of magical power and corruption takes the unique viewpoint of focusing on the evil characters, as we follow them from boys to men. Filled with action, suspense and wonderfully imaginative characters, Water From the Well of Darkness is set to elevate the careers of bestselling authors Weis & Hickman to spectacular new heights.            3.66
# 32    The Bonesetter's Daughter                      Amy Tan                                   China                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Tells the story of three generations of Chinese women, beginning at the turn of the century.            3.98
# 51        A Murder is Announced              Agatha Christie  Detective and mystery stories, English                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    The villagers of Chipping Cleghorn are amazed by an advertisement in the local paper which reads "A murder is announced and will take place on Friday October 29th, at Little Paddocks at 6.30pm. Unable to resist, a crowd begins to gather at the house at the appointed time. But when a man is killed in what looks like an attempted robbery, Miss Marple becomes involved.            3.98
# 58        The Lord of the Rings             J. R. R. Tolkien   Baggins, Frodo (Fictitious character)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Sauron has gathered the Rings of Power - the means by which he will be able to rule the world. All he needs now is the Ruling Ring, which has fallen into the hands of the hobbit Bilbo Baggins. Frodo Baggins is entrusted to foil Sauron's plans.            4.49
# ...                         ...                          ...                                     ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ...             ...
# 6695      Shakespeare's Sonnets          William Shakespeare                                   Drama                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  No Marketing Blurb            4.25
# 6750                McSweeney's                  Dave Eggers                                 Fiction                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Presents a new compilation of writings from the popular literary journal, which began in the 1998 as a small literary journal that published only works rejected from other magazines, including an excerpt from Edmund White's new memoir My Hustlers, as well as works by Jonathan Lethem, William T. Vollmann, David Foster Wallace, Rick Moody, and many new talents.            3.72
# 6754                McSweeney's                  Dave Eggers                                 Fiction                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        With a special section on Donald Barthelme, including remembrances from Ann Beattie, David Gates, and Oscar Hijuelos, and some of Barthelme's barely published and never-collected early work, and a highly theoretical but potentially amazing Z-binding that we can't describe very well here, or even to each other, McSweeney's 24 will never be mistaken for anything else. (Except possibly the June 1978 issue of Popular Mechanics.)            3.81
# 6755                    Erotica                   Kelly Carr                                 Fiction                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               "My Dirty Thirties" takes female empowerment to new levels with a series of erotic novels about women in their 30s who can't say no to their desires. (Adult Fiction)            2.44
# 6756                    Erotica                   Kelly Carr                                 Fiction                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Romantic Hedonism: What happens when a woman meets the man of her dreams in London? She prays her husband doesn't find out. My Dirty Thirties is a series of erotic novels about women in their thirties who can't say no to their desires. Call it "The Thing" or call it sexual peak, but once it happens, there's no turning back. It takes female empowerment to new levels. Romantic Hedonism is the second book in the series.            3.00
#
# [319 rows x 5 columns]

# %%
# Удалим дубликаты по столбцам 'title', 'authors'
df = df.drop_duplicates(subset=['title', 'authors'])

# %%
# маска. Количество пропусков
null_d=df.isnull().sum()
print(null_d[null_d>0])
# Out:
# authors           65
# categories        35
# average_rating    34
# dtype: int64

# %%
# Статистика числовых признаков (average_rating)
df.describe()
# Out:
#        average_rating
# count     6344.000000
# mean         3.930372
# std          0.322904
# min          0.000000
# 25%          3.760000
# 50%          3.950000
# 75%          4.130000
# max          5.000000

# %%
# Заполним пропуски в столбце average_rating случайными значениями от 3 до 5

# Количество пропусков
num_missing = df['average_rating'].isnull().sum()

# Генерация случайных значений с округлением до сотых
random_ratings = np.round(np.random.uniform(3, 5, size=num_missing), 2)
print(random_ratings)

# Заполнение пропусков
df.loc[df['average_rating'].isnull(), 'average_rating'] = random_ratings
# Out:
# [3.04 3.75 3.52 3.56 3.82 3.68 3.01 4.34 3.33 3.05 4.44 3.92 3.54 3.31
#  4.32 3.78 3.12 3.77 3.93 4.27 4.73 4.44 3.5  4.98 3.06 4.73 4.99 4.11
#  3.39 4.2  3.31 4.37 3.63 3.29]

# %%
# маска. Количество пропусков. Избавились ли от пропусков в столбце average_rating?
null_d=df.isnull().sum()
print(null_d[null_d>0])
# Out:
# authors       65
# categories    35
# dtype: int64

# %%
# Пожертвуем 65 строками с отсутствующими авторами
# Удаляем строки, имеющие пропуски в столбце authors       
df = df.dropna(subset=['authors'])

# маска. Количество пропусков
null_d=df.isnull().sum()
print(null_d[null_d>0])
# Out:
# categories    35
# dtype: int64

# %% [markdown]
# ### Сведем 567 уникальных категорий книг к 19 крупным категориям

# %% [markdown]
# - Фантастика (Fantasy)
# - Ужасы (Horror)
# - Роман (Romance)
# - Детектив (Mystery)
# - Приключения (Adventure)
# - Триллеры (Thriller)
# - Мистика (Paranormal)
# - Драма (Drama)
# - Поэзия (Poetry)
# - Биография (Biography)
# - Саморазвитие (Self-help)
# - Психология (Psychology)
# - Экономика (Economics)
# - История (History)
# - Политика (Politics)
# - Бизнес (Business)
# - Кулинария (Cookbook)
# - Технологии (Technology)
# - Искусство и культура (Art & Culture)

# %%
df.sample()
# Out:
#                    title        authors categories                                                                                                                                                                                                                   description  average_rating
# 2335  A Map of the World  Jane Hamilton    Fiction  While under the care of Alice Goodwin, a neighbor's child drowns in the Goodwins' pond, a devastating accident that has profound repercussions for the entire Goodwin family, in a story set in a small Midwestern farm town             3.8

# %%
import torch
print(torch.cuda.is_available())     # должно быть True
# print(torch.cuda.get_device_name(0)) # название видеокарты
# Out:
# True

# %%
device = 0 if torch.cuda.is_available() else -1
print(device)
# Out:
# 0

# %%
# Создадим словарь категорий
major_categories = [
    "Fantasy",
    "Horror",
    "Romance",
    "Mystery",
    "Adventure",
    "Thriller",
    "Paranormal",
    "Drama",
    "Poetry",
    "Biography",
    "Self-help",
    "Psychology",
    "Economics",
    "History",
    "Politics",
    "Business",
    "Cookbook",
    "Technology",
    "Art & Culture"
]

# %%
# Инициализируем zero-shot классификатор. 
# "facebook/bart-large-mnli" - предварительно обученная модель от Meta AI, основанная на архитектуре BART.
from transformers import pipeline

# # Тяжелая модель 1 батч (128) = 43сек:
# classifier = pipeline(
#     "zero-shot-classification",
#     model="facebook/bart-large-mnli",
#     device=device
# )


# # Легче модель 1 батч (128) = 22сек:
# classifier = pipeline(
#     "zero-shot-classification",
#     model="valhalla/distilbart-mnli-12-1",
#     device=device 
# )


# # # Легче модель 1 батч (128) = 38 сек:
# classifier = pipeline(
#     "zero-shot-classification",
#     model="MoritzLaurer/deberta-v3-base-zeroshot-v1",
#     device=device  # GPU
# )



# Тяжелая модель 1 батч (128) = 59 сек:
classifier = pipeline(
    "zero-shot-classification",
    model="MoritzLaurer/DeBERTa-v3-large-mnli-fever-anli-ling-wanli",
    device=device
)
# Out:
# config.json:   0%|          | 0.00/1.06k [00:00<?, ?B/s]
# C:\Users\Konsta\AppData\Roaming\Python\Python38\site-packages\huggingface_hub\file_download.py:144: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\Konsta\.cache\huggingface\hub\models--MoritzLaurer--DeBERTa-v3-large-mnli-fever-anli-ling-wanli. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# model.safetensors:   0%|          | 0.00/870M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/395 [00:00<?, ?B/s]
# spm.model:   0%|          | 0.00/2.46M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/8.65M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/18.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/156 [00:00<?, ?B/s]

# %%
# Подбор категории по двум столбцам:


def map_category_with_description(row):
    # Объединяем информацию из двух столбцов
    input_text = f"{row['categories']}. {row['description']}"
    
    # Классифицируем объединённый текст
    result = classifier(input_text, major_categories)
    
    # Возвращаем наиболее вероятный жанр
    return result['labels'][0]

# %%
# # Проверка скорости на 1 батче

# batch_size = 32
# texts = [f"{row['categories']}. {row['description']}" for _, row in df.iterrows()]
# ## texts = [f"{row['categories']}" for _, row in df.iterrows()]

# # Берём только первый батч
# batch = texts[:batch_size]

# # Классифицируем первый батч
# results = classifier(batch, candidate_labels=major_categories)

# # Пример вывода первой метки из результатов
# print(results[0]['labels'][0])
# Out:
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 33 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 34 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 35 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 36 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 37 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 38 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 39 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 40 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 41 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 42 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 43 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 44 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 45 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 46 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 47 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 48 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 49 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 50 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 51 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 52 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 53 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 54 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 55 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 56 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 57 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 58 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 59 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 60 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 61 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 62 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 63 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 64 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 65 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 66 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 67 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 68 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 69 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 70 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 71 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 72 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 73 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 74 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 75 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 76 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 77 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 78 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 79 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 80 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 81 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 82 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 83 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 84 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 85 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 86 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 87 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 88 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 89 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 90 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 91 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 92 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 93 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 94 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 95 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 96 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 97 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 98 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 99 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 100 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 101 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 102 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 103 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 104 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 105 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 106 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 107 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 108 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 109 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 110 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 111 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 112 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 113 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 114 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 115 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 116 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 117 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 118 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 119 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 120 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 121 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 122 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 123 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 124 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 125 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 126 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 127 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 128 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 129 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 130 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 131 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 132 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 133 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 134 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 135 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 136 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 137 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 138 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 139 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 140 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 141 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 142 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 143 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 144 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 145 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 146 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 147 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 148 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 149 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 150 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 151 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 152 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 153 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 154 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 155 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 156 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 157 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 158 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 159 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 160 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 161 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 162 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 163 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 164 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 165 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 166 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 167 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 168 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 169 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 170 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 171 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 172 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 173 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 174 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 175 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 176 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 177 samples have been fetched.
#   warnings.warn(warn_msg)
# ...
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 561 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 562 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 563 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 564 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 565 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 566 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 567 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 568 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 569 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 570 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 571 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 572 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 573 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 574 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 575 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 576 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 577 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 578 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 579 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 580 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 581 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 582 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 583 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 584 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 585 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 586 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 587 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 588 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 589 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 590 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 591 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 592 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 593 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 594 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 595 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 596 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 597 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 598 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 599 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 600 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 601 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 602 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 603 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 604 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 605 samples have been fetched.
#   warnings.warn(warn_msg)
# Art & Culture
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 606 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 607 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 32(when accessing len(dataloader)), but 608 samples have been fetched.
#   warnings.warn(warn_msg)

# %%
# Подготовка текстов
texts = [f"{row['categories']}. {row['description']}" for _, row in df.iterrows()]

# %%
# Обработка батчами
batch_size = 32
results = []

# %%
# Для 2 столбцов

from tqdm import tqdm


for i in tqdm(range(0, len(texts), batch_size), desc="Выполняется..."):
    batch = texts[i:i + batch_size]
    outputs = classifier(batch, candidate_labels=major_categories)
    
    # Вариант для batched pipeline: список результатов
    if isinstance(outputs, list):
        for out in outputs:
            results.append(out["labels"][0])
    else:  # Вариант на 1 строку
        results.append(outputs["labels"][0])
# Out:
# Выполняется...:   0%|          | 0/198 [00:00<?, ?it/s]c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 33 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 34 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 35 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 36 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 37 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 38 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 39 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 40 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 41 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 42 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 43 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 44 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 45 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 46 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 47 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 48 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 49 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 50 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 51 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 52 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 53 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 54 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 55 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 56 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 57 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 58 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 59 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 60 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 61 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 62 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 63 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 64 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 65 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 66 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 67 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 68 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 69 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 70 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 71 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 72 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 73 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 74 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 75 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 76 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 77 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 78 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 79 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 80 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 81 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 82 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 83 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 84 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 85 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 86 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 87 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 88 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 89 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 90 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 91 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 92 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 93 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 94 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 95 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 96 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 97 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 98 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 99 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 100 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 101 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 102 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 103 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 104 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 105 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 106 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 107 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 108 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 109 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 110 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 111 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 112 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 113 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 114 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 115 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 116 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 117 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 118 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 119 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 120 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 121 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 122 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 123 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 124 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 125 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 126 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 127 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 128 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 129 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 130 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 131 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 132 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 133 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 134 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 135 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 136 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 137 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 138 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 139 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 140 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 141 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 142 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 143 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 144 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 145 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 146 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 147 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 148 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 149 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 150 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 151 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 152 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 153 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 154 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 155 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 156 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 157 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 158 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 159 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 160 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 161 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 162 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 163 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 164 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 165 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 166 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 167 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 168 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 169 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 170 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 171 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 172 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 173 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 174 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 175 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 176 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001EC857DCF40> was reported to be 32(when accessing len(dataloader)), but 177 samples have been fetched.
#   warnings.warn(warn_msg)
# ...
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 9(when accessing len(dataloader)), but 124 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 9(when accessing len(dataloader)), but 125 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 9(when accessing len(dataloader)), but 126 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 9(when accessing len(dataloader)), but 127 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 9(when accessing len(dataloader)), but 128 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 9(when accessing len(dataloader)), but 129 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 9(when accessing len(dataloader)), but 130 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 9(when accessing len(dataloader)), but 131 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 9(when accessing len(dataloader)), but 132 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 9(when accessing len(dataloader)), but 133 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 9(when accessing len(dataloader)), but 134 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 9(when accessing len(dataloader)), but 135 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 9(when accessing len(dataloader)), but 136 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 9(when accessing len(dataloader)), but 137 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 9(when accessing len(dataloader)), but 138 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 9(when accessing len(dataloader)), but 139 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 9(when accessing len(dataloader)), but 140 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 9(when accessing len(dataloader)), but 141 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 9(when accessing len(dataloader)), but 142 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 9(when accessing len(dataloader)), but 143 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 9(when accessing len(dataloader)), but 144 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 9(when accessing len(dataloader)), but 145 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 9(when accessing len(dataloader)), but 146 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 9(when accessing len(dataloader)), but 147 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 9(when accessing len(dataloader)), but 148 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 9(when accessing len(dataloader)), but 149 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 9(when accessing len(dataloader)), but 150 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 9(when accessing len(dataloader)), but 151 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 9(when accessing len(dataloader)), but 152 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 9(when accessing len(dataloader)), but 153 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 9(when accessing len(dataloader)), but 154 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 9(when accessing len(dataloader)), but 155 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 9(when accessing len(dataloader)), but 156 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 9(when accessing len(dataloader)), but 157 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 9(when accessing len(dataloader)), but 158 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 9(when accessing len(dataloader)), but 159 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 9(when accessing len(dataloader)), but 160 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 9(when accessing len(dataloader)), but 161 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 9(when accessing len(dataloader)), but 162 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 9(when accessing len(dataloader)), but 163 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 9(when accessing len(dataloader)), but 164 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 9(when accessing len(dataloader)), but 165 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 9(when accessing len(dataloader)), but 166 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 9(when accessing len(dataloader)), but 167 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 9(when accessing len(dataloader)), but 168 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 9(when accessing len(dataloader)), but 169 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 9(when accessing len(dataloader)), but 170 samples have been fetched.
#   warnings.warn(warn_msg)
# c:\ProgramData\anaconda3\envs\myenv\lib\site-packages\torch\utils\data\dataloader.py:641: UserWarning: Length of IterableDataset <transformers.pipelines.pt_utils.PipelineChunkIterator object at 0x000001ECC7893EE0> was reported to be 9(when accessing len(dataloader)), but 171 samples have been fetched.
#   warnings.warn(warn_msg)
# Выполняется...: 100%|██████████| 198/198 [44:17<00:00, 13.42s/it]

# %%
# Сохраняем результат
df["categories_new"] = results

# %%
df.to_csv("Book_recom_small+new_categ.csv", index=False)

# %%
df.head(1)
# Out:
#     title             authors categories                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         description  average_rating categories_new
# 0  Gilead  Marilynne Robinson    Fiction  A NOVEL THAT READERS and critics have been eagerly anticipating for over a decade, Gilead is an astonishingly imagined story of remarkable lives. John Ames is a preacher, the son of a preacher and the grandson (both maternal and paternal) of preachers. It’s 1956 in Gilead, Iowa, towards the end of the Reverend Ames’s life, and he is absorbed in recording his family’s story, a legacy for the young son he will never see grow up. Haunted by his grandfather’s presence, John tells of the rift between his grandfather and his father: the elder, an angry visionary who fought for the abolitionist cause, and his son, an ardent pacifist. He is troubled, too, by his prodigal namesake, Jack (John Ames) Boughton, his best friend’s lost son who returns to Gilead searching for forgiveness and redemption. Told in John Ames’s joyous, rambling voice that finds beauty, humour and truth in the smallest of life’s details, Gilead is a song of celebration and acceptance of the best and the worst the world has to offer. At its heart is a tale of the sacred bonds between fathers and sons, pitch-perfect in style and story, set to dazzle critics and readers alike.            3.85  Art & Culture

# %%
# Сохраняем как Excel
df.to_excel("Book_recom_small+new_categ.xlsx", index=False)

# %%
# Удалим столбец со старыми жанрами

df = df.drop(columns=["categories"])

# %% [markdown]
# ### Вернем колонку со ссылками на картинки

# %%
# Загрузим изначальный датасет
processed_data = pd.read_csv('1/Books.csv')

df_2 = pd.DataFrame(processed_data)

# %%
df_2.sample(1)
# Out:
#              isbn13      isbn10                                title                                                     subtitle     authors categories                                                                                              thumbnail                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   description  published_year  average_rating  num_pages  ratings_count
# 5435  9780872201682  0872201686  On Justice, Power, and Human Nature  The Essence of Thucydides' History of the Peloponnesian War  Thucydides    History  http://books.google.com/books/content?id=j2VgQgAACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api  Designed for students with little or no background in ancient Greek language and culture, this collection of extracts from The History of the Peloponnesian War includes those passages that shed most light on Thucydides' political theory--famous as well as important but lesser-known pieces frequently overlooked by nonspecialists. Newly translated into spare, vigorous English, and situated within a connective narrative framework, Woodruff's selections will be of special interest to instructors in political theory and Greek civilization. Includes maps, notes, glossary.          1993.0            3.72      172.0          567.0

# %%
df.sample(1)
# Out:
#              title       authors                                                                                                                                                                                                                                        description  average_rating categories_new
# 1975  Dream Makers  Nora Roberts  Lion trainer Jo Wilder finds herself falling for Keane Prescott, a lawyer who inherits ownership of the circus; and, Megan Miller finds herself falling for David Katcherton, a sexy stranger who offers to buy her grandfather's amusement park.            3.81        Fantasy

# %%
# Добавим столбец с ссылками на изображения по столбам title и authors
df_small_finish = df.merge(
    df_2[["title", "authors", "description", "thumbnail"]],
    on=["title", "authors", "description"],
    how="left"
)

# %%
df_small_finish.sample(1)
# Out:
#                      title          authors                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          description  average_rating categories_new                                                                                              thumbnail
# 562  The Elephant Vanishes  Haruki Murakami  When a man's favourite elephant vanishes, the balance of his whole life is subtly upset; a couple's midnight hunger pangs drive them to hold up a McDonald's; a woman finds she is irresistible to a small green monster that burrows through her front garden; an insomniac wife wakes up to a twilight world of semi-consciousness in which anything seems possible - even death. In every one of the stories that make up The Elephant Vanishes, Murakami makes a determined assault on the normal. He has a deadpan genius for dislocating realities to uncover the surreal in the everyday, the extraordinary in the ordinary.            3.86        Fantasy  http://books.google.com/books/content?id=GzP6Dzk-f8sC&printsec=frontcover&img=1&zoom=1&source=gbs_api

# %%
df_small_finish.to_csv("Book_recom_small_FINISH.csv", index=False)

# %%
df_small_finish.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6323 entries, 0 to 6322
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           6323 non-null   object
#  1   authors         6323 non-null   object
#  2   description     6323 non-null   object
#  3   average_rating  6323 non-null   float64
#  4   categories_new  6323 non-null   object
#  5   thumbnail       6124 non-null   object
# dtypes: float64(1), object(5)
# memory usage: 296.5+ KB

# %%
# маска. Количество пропусков
null_d=df_small_finish.isnull().sum()
print(null_d[null_d>0])
# Out:
# thumbnail    199
# dtype: int64

# %%
# Проверка на дубликаты по столбцам 'title' и 'authors'
duplicates = df_small_finish[df_small_finish.duplicated(subset=['title', 'authors'], keep=False)]

# Вывод всех найденных дубликатов
print("Найдено дубликатов:", duplicates.shape[0])
print(duplicates)
# Out:
# Найдено дубликатов: 20
#                              title                      authors                                                                                                                                                                                                                                                                                                                          description  average_rating categories_new                                                                                                        thumbnail
# 971              A Little Princess      Frances Hodgson Burnett                                                                                                                                                                                        Sara Crewe, a pupil at Miss Minchin's London school, is left in poverty when her father dies but is later rescued by a mysterious benefactor.            4.19        Mystery            http://books.google.com/books/content?id=7_8uF1mO9icC&printsec=frontcover&img=1&zoom=1&source=gbs_api
# 972              A Little Princess      Frances Hodgson Burnett                                                                                                                                                                                        Sara Crewe, a pupil at Miss Minchin's London school, is left in poverty when her father dies but is later rescued by a mysterious benefactor.            4.19        Mystery            http://books.google.com/books/content?id=uQJRYS6oN7YC&printsec=frontcover&img=1&zoom=1&source=gbs_api
# 975                    On the Road                 Jack Kerouac                                                                                                                                                                                             Follows the counterculture escapades of members of the Beat generation as they seek pleasure and meaning while traveling coast to coast.            3.63        Fantasy            http://books.google.com/books/content?id=4w1vQRkAVxYC&printsec=frontcover&img=1&zoom=1&source=gbs_api
# 976                    On the Road                 Jack Kerouac                                                                                                                                                                                             Follows the counterculture escapades of members of the Beat generation as they seek pleasure and meaning while traveling coast to coast.            3.63        Fantasy            http://books.google.com/books/content?id=2ioLwQEACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api
# 2075            The Amber Spyglass               Philip Pullman                                                                                                                                                                                        Lyra and Will find themselves at the center of a battle between the forces of the Authority and those gathered by Lyra's father, Lord Asriel.            4.09        Fantasy            http://books.google.com/books/content?id=7EglAQAAIAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api
# 2076            The Amber Spyglass               Philip Pullman                                                                                                                                                                                        Lyra and Will find themselves at the center of a battle between the forces of the Authority and those gathered by Lyra's father, Lord Asriel.            4.09        Fantasy            http://books.google.com/books/content?id=VIaPPgAACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api
# 2190         History of Philosophy  Frederick Charles Copleston                                                                                                                                                                                                                                        Evaluates important elements of Western philosophy from its classical origins to the present.            4.08      Self-help            http://books.google.com/books/content?id=NvoLvAEACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api
# 2191         History of Philosophy  Frederick Charles Copleston                                                                                                                                                                                                                                        Evaluates important elements of Western philosophy from its classical origins to the present.            4.08      Self-help            http://books.google.com/books/content?id=_cxGPgAACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api
# 3103             The Secret Garden      Frances Hodgson Burnett                                                                                                                                                                             A ten-year-old orphan comes to live in a lonely house on the Yorkshire moors where she discovers an invalid cousin and the mysteries of a locked garden.            4.13  Art & Culture            http://books.google.com/books/content?id=oGNbnTQdiJ4C&printsec=frontcover&img=1&zoom=1&source=gbs_api
# 3104             The Secret Garden      Frances Hodgson Burnett                                                                                                                                                                             A ten-year-old orphan comes to live in a lonely house on the Yorkshire moors where she discovers an invalid cousin and the mysteries of a locked garden.            4.13  Art & Culture  http://books.google.com/books/content?id=f_9CD4Ox2AEC&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api
# 3521  The Heart is a Lonely Hunter             Carson McCullers                                                                                                                                                                                                                                                    A quiet, sensitive girl searches for beauty in a small, but damned Southern town.            3.98        Fantasy            http://books.google.com/books/content?id=HdCPQgAACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api
# 3522  The Heart is a Lonely Hunter             Carson McCullers                                                                                                                                                                                                                                                    A quiet, sensitive girl searches for beauty in a small, but damned Southern town.            3.98        Fantasy  http://books.google.com/books/content?id=z_Pvxz9iRJ0C&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api
# 4175                 Twelfth Night          William Shakespeare                                                                                                                                                                                          Background information about Shakespeare, Elizabethan theater, and the text accompany his play about unrequited love and mistaken identity.            3.98          Drama            http://books.google.com/books/content?id=auH_ngEACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api
# 4176                 Twelfth Night          William Shakespeare                                                                                                                                                                                          Background information about Shakespeare, Elizabethan theater, and the text accompany his play about unrequited love and mistaken identity.            3.98          Drama  http://books.google.com/books/content?id=DPQ2dddy3_gC&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api
# 4384             A Christmas Carol              Charles Dickens                                                                                                                                                                                                                    A miser learns the true meaning of Christmas when three ghostly visitors review his past and foretell his future.            4.04     Paranormal                                                                                                              NaN
# 4385             A Christmas Carol              Charles Dickens                                                                                                                                                                                                                    A miser learns the true meaning of Christmas when three ghostly visitors review his past and foretell his future.            4.04     Paranormal            http://books.google.com/books/content?id=A8D33OzY0U4C&printsec=frontcover&img=1&zoom=1&source=gbs_api
# 5533           Fullmetal Alchemist               Hiromu Arakawa  In an alchemical ritual gone wrong, Edward Elric lost his arm and his leg, and his brother Alphonse became nothing but a soul in a suit of armor. Equipped with mechanical "auto-mail" limbs, Edward becomes a state alchemist, seeking the one thing that can restore his brother and himself...the legendary Philosopher's Stone.            4.57        Fantasy            http://books.google.com/books/content?id=syuslnDB9OMC&printsec=frontcover&img=1&zoom=1&source=gbs_api
# 5534           Fullmetal Alchemist               Hiromu Arakawa  In an alchemical ritual gone wrong, Edward Elric lost his arm and his leg, and his brother Alphonse became nothing but a soul in a suit of armor. Equipped with mechanical "auto-mail" limbs, Edward becomes a state alchemist, seeking the one thing that can restore his brother and himself...the legendary Philosopher's Stone.            4.57        Fantasy            http://books.google.com/books/content?id=ndMZyQEACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api
# 6212         Strangers in Paradise                  Terry Moore                                                                                                                                                                                                   Chronicles the relationship between three friends--Katchoo, Francine, and David--and the people they fall in and out of love with.            4.09        Romance            http://books.google.com/books/content?id=8BeQCEcju3QC&printsec=frontcover&img=1&zoom=1&source=gbs_api
# 6213         Strangers in Paradise                  Terry Moore                                                                                                                                                                                                   Chronicles the relationship between three friends--Katchoo, Francine, and David--and the people they fall in and out of love with.            4.09        Romance            http://books.google.com/books/content?id=d7kLuwEACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api

# %%
# Удалим дубликаты по столбцам 'title', 'authors'
df_small_finish = df_small_finish.drop_duplicates(subset=['title', 'authors'])

# %%
df_small_finish.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6313 entries, 0 to 6322
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           6313 non-null   object
#  1   authors         6313 non-null   object
#  2   description     6313 non-null   object
#  3   average_rating  6313 non-null   float64
#  4   categories_new  6313 non-null   object
#  5   thumbnail       6114 non-null   object
# dtypes: float64(1), object(5)
# memory usage: 345.2+ KB

# %%
# маска. Количество пропусков
null_d=df_small_finish.isnull().sum()
print(null_d[null_d>0])
# Out:
# thumbnail    199
# dtype: int64

# %%
# Добавим картинки к книгам, где отстутсвуют ссылки в соответствии с жанром:

# создадим словарь
category_to_image = {
    "Fantasy": "https://raw.github.com/Kosty1703/pictures/main/Pictures/Fantasy.jpg",
    "Horror": "https://raw.github.com/Kosty1703/pictures/main/Pictures/Fantasy.jpg",
    "Romance": "https://raw.github.com/Kosty1703/pictures/main/Pictures/Romance.jpg",
    "Mystery": "https://raw.github.com/Kosty1703/pictures/main/Pictures/Mystery.jpg",
    "Adventure": "https://raw.github.com/Kosty1703/pictures/main/Pictures/Adventure.jpg",
    "Thriller": "https://raw.github.com/Kosty1703/pictures/main/Pictures/Thriller.jpg",
    "Paranormal": "https://raw.github.com/Kosty1703/pictures/main/Pictures/Paranormal.jpg",
    "Drama": "https://raw.github.com/Kosty1703/pictures/main/Pictures/Drama.jpg",
    "Poetry": "https://raw.github.com/Kosty1703/pictures/main/Pictures/Poetry.jpg",
    "Biography": "https://raw.github.com/Kosty1703/pictures/main/Pictures/Biography.jpg",
    "Self-help": "https://raw.github.com/Kosty1703/pictures/main/Pictures/Self-help.jpg",
    "Psychology": "https://raw.github.com/Kosty1703/pictures/main/Pictures/Psychology.jpg",
    "Economics": "https://raw.github.com/Kosty1703/pictures/main/Pictures/Economics.jpg",
    "History": "https://raw.github.com/Kosty1703/pictures/main/Pictures/History.jpg",
    "Politics": "https://raw.github.com/Kosty1703/pictures/main/Pictures/Politics.jpg",
    "Business": "https://raw.github.com/Kosty1703/pictures/main/Pictures/Business.jpg",
    "Cookbook": "https://raw.github.com/Kosty1703/pictures/main/Pictures/Cookbook.jpg",
    "Technology": "https://raw.github.com/Kosty1703/pictures/main/Pictures/Technology.jpg",
    "Art & Culture": "https://raw.github.com/Kosty1703/pictures/main/Pictures/Art%20%26%20Culture.jpg"
}

# %%
# Подставляем ссылки из словаря только на пустые места в столбце thumbnail
df_small_finish["thumbnail"] = df_small_finish.apply(
    lambda row: category_to_image[row["categories_new"]] if pd.isna(row["thumbnail"]) else row["thumbnail"],
    axis=1
)

# %%
df_small_finish.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6313 entries, 0 to 6322
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           6313 non-null   object
#  1   authors         6313 non-null   object
#  2   description     6313 non-null   object
#  3   average_rating  6313 non-null   float64
#  4   categories_new  6313 non-null   object
#  5   thumbnail       6313 non-null   object
# dtypes: float64(1), object(5)
# memory usage: 345.2+ KB

# %%
# маска. Количество пропусков
null_d=df_small_finish.isnull().sum()
print(null_d[null_d>0])
# Out:
# Series([], dtype: int64)

# %%
df_small_finish.sample(1)
# Out:
#                     title               authors                                                                                                                                                                                                                                              description  average_rating categories_new                                                                                              thumbnail
# 4965  Wonder of the World  David Lindsay-Abaire  THE STORY: Nothing will prepare you for the dirty little secret Cass discovers in her husband's sweater drawer. It is so shocking that our heroine has no choice but to flee to the honeymoon capital of the world in a frantic search for the life she            3.94          Drama  http://books.google.com/books/content?id=t1eMMBLXGd0C&printsec=frontcover&img=1&zoom=1&source=gbs_api

# %%
# Переименуем столбцы в один формат со вторым датасетом для последующего слияния.
df_small_finish = df_small_finish.rename(columns={"title": "Title"})
df_small_finish = df_small_finish.rename(columns={"authors": "Authors"})
df_small_finish = df_small_finish.rename(columns={"description": "Description"})
df_small_finish = df_small_finish.rename(columns={"categories_new": "Category"})
df_small_finish = df_small_finish.rename(columns={"average_rating": "Rating"})
df_small_finish = df_small_finish.rename(columns={"thumbnail": "Link"})
df_small_finish.sample(1)
# Out:
#           Title      Authors                                                                                                                                                                                                                                                                                                                            Description  Rating   Category                                                                                                   Link
# 3533  Two of Us  Peter Smith  The author of A Good Family offers poignant, entertaining account of how his and his son's mutual love for the music of the Beatles sparked a closer relationship, describing how they used the songs and exploits of the Fab Four to spark discussions of such topics as friendship, teamwork, art, sorrow, failure, and mortalitiy.    3.53  Biography  http://books.google.com/books/content?id=GhRKYgEACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api

# %%
df_small_finish.to_csv("Book_recom_small_FINISH.csv", index=False)
